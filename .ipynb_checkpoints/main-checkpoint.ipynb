# %%
import pandas as pd

df = pd.read_csv('flight-data.csv')

# %%
print(df.head(3))
# Out:
#    Unnamed: 0 Origin_Airport Destination_Airport Operating_Airline model  \
# 0           0           EDDF                EDDT                LH  A321
# 1           1           EDDT                EDDF                LH  A321
# 2           2           ENBR                ENGM                DY  B738
#
#   _Manufacturer  seats  distance  _Operating_Airline_ASK_(Millions)  depcount  \
# 0        Airbus  201.0     433.0                         358.837059    4123.0
# 1        Airbus  201.0     433.0                         358.662993    4121.0
# 2        Boeing  186.0     304.0                         223.688064    3956.0
#
#    ...         co2t         soxt  taxi_fuel  CAT        dist  mean_taxi_in  \
# 0  ...  27725432.03  7370.051552   0.220812    D  420.062088      4.973456
# 1  ...  27727074.65  7370.488196   0.220812    D  420.062088      8.948679
# 2  ...  19728452.98  5244.272310   0.232000    D  294.916570      4.582232
#
#    std_taxi_in mean_taxi_out  std_taxi_out  fuel_burn_total
# 0     2.035434     14.071969      6.067549        28.192454
# 1     3.738626     10.189412      2.984465        28.220720
# 2     2.038609      9.840005      5.199513        32.429667
#
# [3 rows x 29 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58125 entries, 0 to 58124
# Data columns (total 29 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         58125 non-null  int64
#  1   Origin_Airport                     58125 non-null  object
#  2   Destination_Airport                58125 non-null  object
#  3   Operating_Airline                  58124 non-null  object
#  4   model                              58125 non-null  object
#  5   _Manufacturer                      58125 non-null  object
#  6   seats                              58125 non-null  float64
#  7   distance                           58125 non-null  float64
#  8   _Operating_Airline_ASK_(Millions)  58125 non-null  float64
#  9   depcount                           58125 non-null  float64
#  10  Operating_Airline_Capacity         58125 non-null  float64
#  11  FLIGHT_ID                          58125 non-null  float64
#  12  FFLOW_KGM                          58125 non-null  float64
#  13  fuel_burn                          58125 non-null  float64
#  14  NOX                                58125 non-null  float64
#  15  CO2                                58125 non-null  float64
#  16  SOX                                58125 non-null  float64
#  17  J/T                                58125 non-null  object
#  18  noxt                               58125 non-null  float64
#  19  co2t                               58125 non-null  float64
#  20  soxt                               58125 non-null  float64
#  21  taxi_fuel                          58125 non-null  float64
#  22  CAT                                58125 non-null  object
#  23  dist                               58125 non-null  float64
#  24  mean_taxi_in                       58125 non-null  float64
#  25  std_taxi_in                        52198 non-null  float64
#  26  mean_taxi_out                      58125 non-null  float64
#  27  std_taxi_out                       53589 non-null  float64
#  28  fuel_burn_total                    58125 non-null  float64
# dtypes: float64(21), int64(1), object(7)
# memory usage: 12.9+ MB
# None

# %%
# Out:
# Unnamed: 0                              0
# Origin_Airport                          0
# Destination_Airport                     0
# Operating_Airline                       1
# model                                   0
# _Manufacturer                           0
# seats                                   0
# distance                                0
# _Operating_Airline_ASK_(Millions)       0
# depcount                                0
# Operating_Airline_Capacity              0
# FLIGHT_ID                               0
# FFLOW_KGM                               0
# fuel_burn                               0
# NOX                                     0
# CO2                                     0
# SOX                                     0
# J/T                                     0
# noxt                                    0
# co2t                                    0
# soxt                                    0
# taxi_fuel                               0
# CAT                                     0
# dist                                    0
# mean_taxi_in                            0
# std_taxi_in                          5927
# mean_taxi_out                           0
# std_taxi_out                         4536
# fuel_burn_total                         0
# dtype: int64

# %%
avg_fuel_burn_by_model = df.groupby('model')['fuel_burn'].mean()
print(avg_fuel_burn_by_model)
# Out:
# model
# A140      803.883333
# A148     2636.535324
# A306    21190.284265
# A310    21448.348412
# A318     2998.629387
#             ...
# T134     4930.491899
# T154    11363.968977
# T204     7039.395186
# YK40     7798.350074
# YK42     6682.194003
# Name: fuel_burn, Length: 91, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.scatter(df['distance'], df['fuel_burn'])
plt.xlabel('Distance')
plt.ylabel('Fuel Burn')
plt.title('Distance vs Fuel Burn')
plt.show()

# %%
df.plot.scatter(x='distance', y='CO2', title='Distance vs CO2 Emissions')
# Out:
# <Axes: title={'center': 'Distance vs CO2 Emissions'}, xlabel='distance', ylabel='CO2'>

# %%
avg_fuel_burn_by_origin = df.groupby('Origin_Airport')['fuel_burn'].mean()
avg_fuel_burn_by_destination = df.groupby('Destination_Airport')['fuel_burn'].mean()
print(avg_fuel_burn_by_origin)
print(avg_fuel_burn_by_destination)
# Out:
# Origin_Airport
# BIAR      945.900000
# BIEG      598.350000
# BIIS      233.150000
# BIKF    11732.078991
# BIRK     1278.126187
#             ...
# UWPP     1920.359523
# UWSS     2662.017157
# UWUU     4310.059968
# UWWW     4209.232013
# YXCM      631.550000
# Name: fuel_burn, Length: 673, dtype: float64
# Destination_Airport
# BGBW     4512.635688
# BGGH     1369.266667
# BGJN     1350.750000
# BGKK      935.066667
# BGSF    10673.801604
#             ...
# ZYCC     2135.501001
# ZYHB     5142.529035
# ZYJM      735.190665
# ZYTL     3263.659952
# ZYTX    13986.513199
# Name: fuel_burn, Length: 1052, dtype: float64

# %%
print(df[['mean_taxi_in', 'mean_taxi_out']].mean())
# Out:
# mean_taxi_in      5.756504
# mean_taxi_out    12.147458
# dtype: float64

# %%
avg_fuel_burn_by_manufacturer = df.groupby('_Manufacturer')['fuel_burn'].mean().sort_values()

print(avg_fuel_burn_by_manufacturer)
# Out:
# _Manufacturer
# Antonov      1720.210000
# Yakovlev     7240.270000
# Tupolev      7777.953333
# Airbus      15212.420000
# Name: fuel_burn, dtype: float64

# %%
df.describe()
# Out:
#          Unnamed: 0         seats      distance  \
# count  58125.000000  58125.000000  58125.000000
# mean   29062.000000    160.415604   1690.426735
# std    16779.386535     58.680718   1575.927078
# min        0.000000      7.000000    100.000000
# 25%    14531.000000    130.000000    721.000000
# 50%    29062.000000    170.000000   1286.000000
# 75%    43593.000000    189.000000   2034.000000
# max    58124.000000    564.000000  11961.000000
#
#        _Operating_Airline_ASK_(Millions)      depcount  \
# count                       58125.000000  58125.000000
# mean                           36.864982    134.058925
# std                           117.452812    247.317220
# min                             0.004212      1.000000
# 25%                             1.593072     10.000000
# 50%                             7.824171     43.000000
# 75%                            29.199024    145.000000
# max                          6138.482400   5003.000000
#
#        Operating_Airline_Capacity     FLIGHT_ID     FFLOW_KGM      fuel_burn  \
# count                5.812500e+04  58125.000000  58125.000000   58125.000000
# mean                 3.686498e+07  29063.000000     42.011867    8689.542926
# std                  1.174528e+08  16779.386535     25.236221   23471.663577
# min                  4.212000e+03      1.000000      0.000000      67.900000
# 25%                  1.593072e+06  14532.000000     37.185052    2373.495655
# 50%                  7.824171e+06  29063.000000     39.750772    4046.614148
# 75%                  2.919902e+07  43594.000000     43.818889    6327.326400
# max                  6.138482e+09  58125.000000    311.001605  388578.204100
#
#                 NOX  ...          noxt          co2t           soxt  \
# count  58125.000000  ...  5.812500e+04  5.812500e+04   58125.000000
# mean     133.949013  ...  1.864661e+04  3.593661e+06     955.276922
# std      448.205375  ...  1.251886e+05  1.961791e+07    5214.886161
# min        0.000000  ...  0.000000e+00  3.036760e+02       0.080724
# 25%       34.893234  ...  3.323993e+02  1.142386e+05      30.367211
# 50%       57.891788  ...  2.079001e+03  5.322186e+05     141.475823
# 75%       88.199734  ...  8.152510e+03  1.868733e+06     496.751725
# max     8840.993481  ...  8.672804e+06  1.213245e+09  322508.251100
#
#           taxi_fuel          dist  mean_taxi_in   std_taxi_in  mean_taxi_out  \
# count  58125.000000  58125.000000  58125.000000  58125.000000   58125.000000
# mean       0.230240   1639.917283      5.756504      2.092400      12.147458
# std        0.092335   1528.838842      1.820874      1.275672       2.991612
# min        0.130000     97.012029      1.884013      0.000000       3.463768
# 25%        0.208830    699.456733      4.542465      1.541286      10.397840
# 50%        0.212254   1247.574699      5.437532      1.975966      11.931344
# 75%        0.232000   1973.224680      6.369744      2.530108      13.606017
# max        1.100000  11603.608847     14.306735      9.166957      22.896797
#
#        std_taxi_out  fuel_burn_total
# count  58125.000000     58125.000000
# mean       4.454921        26.829606
# std        2.069253        18.212739
# min        0.000000         3.236051
# 25%        3.336662        19.209840
# 50%        4.431190        22.828079
# 75%        5.585610        29.095744
# max       11.544181       995.787090
#
# [8 rows x 22 columns]
